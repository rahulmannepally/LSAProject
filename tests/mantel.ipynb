# %%
#import
import os.path
from gensim import corpora
from gensim.models import LsiModel
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn as s
import dataframe_image as dfi
import networkx as nx
import mantel

# %%
def load_data(path,file_name):
    """
    Input  : path and file_name
    Purpose: loading text file
    Output : list of paragraphs/documents and
             title(initial 100 words considred as title of document)
    """
    documents_list = []
    titles=[]
    document = ''
    i=0
    with open( os.path.join(path, file_name) ,"r") as fin:
        data = fin.read()
        words = data.split()
        fin.seek(0)
        print('Number of words in text file :', len(words))
        for line in fin.readlines():
            text = line.strip()
            i=i+1
            if text !='':
                document = document+text
                if text == 'NEW_ARTICLE':
                    documents_list.append(document)
                    document = ''
        documents_list.append(document)
    print("Total Number of Documents:",len(documents_list))
    titles.append( text[0:min(len(text),100)] )
    return documents_list,titles,len(words)

# %%
document_list,titles,word_count_a=load_data("","law-texts-all.txt")
# Out:
# Number of words in text file : 45105
# Total Number of Documents: 3

# %%
def preprocess_data(doc_set):
    """
    Input  : docuemnt list
    Purpose: preprocess text (tokenize, removing stopwords, and stemming)
    Output : preprocessed text
    """
    # initialize regex tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    # create English stop words list
    en_stop = set(stopwords.words('english'))
    # Create p_stemmer of class PorterStemmer
    p_stemmer = PorterStemmer()
    # list for tokenized documents in loop
    texts = []
    # loop through document list
    for i in doc_set:
        # clean and tokenize document string
        raw = i.lower()
        tokens = tokenizer.tokenize(raw)
        tokens = [i for i in tokens if len(i)>3]
        print(tokens)
        # remove stop words from tokens
        stopped_tokens = [i for i in tokens if not i in en_stop]
        # stem tokens
        stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
        # add tokens to list
        texts.append(stemmed_tokens)
    return texts

# %%
clean_text_a=preprocess_data(document_list)
# Out:
# ['regina', 'secretary', 'state', 'homedepartment', 'parte', 'hindley', 'court', 'appeal', '2000', '152hearing', 'dates', 'october', 'november', '19985', 'november', '1998catchwords', 'prisons', 'prisoners', 'rights', 'release', 'licence', 'mandatory', 'life', 'sentence', 'prisoner', 'tariff', 'element', 'determinate', 'length', 'provisionally', 'fixed', 'communicated', 'prisoner', 'whole', 'life', 'tariff', 'subsequently', 'fixed', 'communicated', 'policy', 'review', 'whole', 'life', 'tariff', 'limited', 'considerations', 'retribution', 'deterrence', 'later', 'amended', 'take', 'account', 'exceptional', 'circumstances', 'whether', 'increase', 'from', 'determinate', 'tariff', 'whole', 'life', 'tariff', 'lawful', 'whether', 'review', 'policy', 'lawful', 'criminal', 'justice', '1991', 'crime', 'sentences', '1997', '29headnote', '1966', 'applicant', 'defendant', 'were', 'convicted', 'murder', 'children', 'received', 'mandatory', 'life', 'sentences', 'applicant', 'also', 'convicted', 'being', 'accessory', 'after', 'fact', 'murder', 'third', 'child', 'which', 'defendant', 'convicted', 'sentenced', 'determinate', 'custodial', 'term', 'immediately', 'following', 'trial', 'judge', 'expressed', 'expectation', 'home', 'office', 'that', 'applicant', 'would', 'kept', 'prison', 'very', 'long', 'time', 'that', 'defendant', 'would', 'released', 'foreseeable', 'future', 'review', 'question', 'release', 'deferred', 'until', '1982', 'when', 'response', 'secretary', 'state', 'request', 'lord', 'chief', 'justice', 'recommended', 'that', 'while', 'would', 'never', 'release', 'defendant', 'term', 'less', 'than25', 'years', 'would', 'appropriate', 'applicant', 'november', '1983', 'secretary', 'state', 'statement', 'parliament', 'announced', 'policy', 'release', 'mandatory', 'life', 'sentence', 'prisoners', 'exercise', 'discretion', 'under', 'criminal', 'justice', '1967', 'particular', 'that', 'sexual', 'sadistic', 'child', 'murderers', 'could', 'normally', 'expect', 'serve', 'tariff', 'period', 'least', 'years', 'satisfy', 'requirements', 'retribution', 'deterrence', 'although', 'longer', 'period', 'might', 'necessary', 'certain', 'cases', 'that', 'first', 'review', 'would', 'take', 'place', 'three', 'years', 'before', 'expiry', 'tariff', 'term', 'january', '1985', 'further', 'consultation', 'lord', 'chief', 'justice', 'confirmed', 'recommendation', 'secretary', 'state', 'reached', 'provisional', 'conclusion', 'that', 'years', 'would', 'appropriate', 'period', 'applicant', 'years', 'defendant', 'march', '1985', 'secretary', 'state', 'announced', 'parliament', 'that', 'case', 'prisoners', 'whose', 'tariff', 'longer', 'than', 'years', 'first', 'formal', 'review', 'parole', 'board', 'would', 'take', 'place', 'after', 'years', 'custody', 'referred', 'cases', 'applicant', 'defendant', 'board', 'which', 'declined', 'recommend', 'their', 'release', 'decided', 'review', 'case', 'applicant', 'five', 'years', 'that', 'defendant', 'years', 'that', 'time', 'applicant', 'told', 'could', 'have', 'calculated', 'provisional', 'year', 'period', '1987', 'applicant', 'confessed', 'police', 'complicity', 'murder', 'third', 'child', 'which', 'defendant', 'been', 'convicted', '1966', 'other', 'children', '1990', 'secretary', 'state', 'concluded', 'that', 'only', 'whole', 'life', 'tariff', 'appropriate', 'applicant', 'case', 'policy', 'announced', 'parliament', 'july', '1993', 'secretary', 'state', 'stated', 'that', 'exercise', 'release', 'discretion', 'confirmed', 'section', 'criminal', 'justice', '1991', 'prisoner', 'would', 'informed', 'tariff', 'judicial', 'recommendations', 'reasons', 'departing', 'from', 'them', 'that', 'exceptionally', 'tariff', 'might', 'increased', 'reduced', 'that', 'prisoner', 'might', 'make', 'representations', 'against', 'such', 'proposed', 'increase', 'december', '1994', 'secretary', 'state', 'announced', 'policy', 'respect', 'those', 'serving', 'whole', 'life', 'tariff', 'that', 'there', 'would', 'periodic', 'ministerial', 'review', 'after', ...
# ['hindley', 'higgins', 'anothercourt', 'appeal', 'civil', 'division', 'unbound', 'transcript', '1011hearing', 'dates', 'august', '198324', 'august', '1983counsel', 'hoffmann', 'hackson', 'appellants', 'skone', 'james', 'respondent', 'panel', 'griffiths', 'kerr', 'ljjjudgmentby', 'griffiths', 'ljjudgment', 'griffiths', 'this', 'appeal', 'stuart', 'higgins', 'journalist', 'employed', 'news', 'group', 'newspapers', 'limited', 'that', 'company', 'publishers', 'newspaper', 'from', 'refusal', 'justice', 'mervyn', 'davies', 'lift', 'interlocutory', 'injunction', 'obtained', 'miss', 'myra', 'hindley', 'preventing', 'further', 'publication', 'series', 'articles', 'which', 'newspaper', 'proposed', 'publish', 'during', 'course', 'this', 'week', 'although', 'form', 'injunction', 'obtained', 'miss', 'myra', 'hindley', 'injunction', 'until', 'friday', 'only', 'this', 'week', 'been', 'agreed', 'between', 'parties', 'that', 'this', 'hearing', 'should', 'treated', 'determining', 'whether', 'those', 'injunctions', 'should', 'until', 'trial', 'action', 'matter', 'arises', 'against', 'following', 'background', 'fact', 'miss', 'myra', 'hindley', 'common', 'knowledge', '1966', 'convicted', 'with', 'named', 'brady', 'murder', 'children', 'commonly', 'known', 'moors', 'murders', 'august', '1978', 'wrote', 'very', 'lengthy', 'submission', 'support', 'application', 'considered', 'parole', 'statement', 'headed', 'follows', 'statement', 'donnelly', 'solicitor', 'eventual', 'perusal', 'home', 'secretary', 'members', 'parole', 'board', 'including', 'chairman', 'dated', 'statement', 'written', 'wholly', 'handwriting', 'miss', 'hindley', 'herself', 'prepared', 'depose', 'upon', 'affidavit', 'because', 'present', 'confinement', 'prison', 'been', 'possible', 'swear', 'affidavit', 'that', 'intended', 'very', 'limited', 'number', 'persons', 'that', 'document', 'they', 'were', 'limited', 'those', 'members', 'parole', 'board', 'before', 'whom', 'application', 'might', 'come', 'lord', 'longford', 'interested', 'supporting', 'plea', 'parole', 'other', 'lady', 'psychiatrist', 'some', 'manner', 'which', 'explained', 'court', 'referred', 'affidavit', 'first', 'defendant', 'stuart', 'higgins', 'copy', 'that', 'application', 'came', 'into', 'hands', 'sworn', 'affidavit', 'which', 'reads', 'follows', 'have', 'been', 'four', 'half', 'years', 'journalist', 'with', 'which', 'published', 'second', 'defendants', 'monday', 'this', 'week', 'began', 'publishing', 'series', 'articles', 'relating', 'plaintiff', 'which', 'intended', 'over', 'number', 'days', 'responsible', 'researching', 'writing', 'this', 'series', 'unable', 'reveal', 'from', 'whom', 'obtained', 'copy', 'letter', 'made', 'available', 'source', 'whom', 'believe', 'reputable', 'whom', 'believe', 'legitimately', 'possession', 'then', 'exhibits', 'affidavit', 'certain', 'newspaper', 'articles', 'which', 'shall', 'have', 'refer', 'hereafter', 'observed', 'that', 'that', 'affidavit', 'higgins', 'does', 'assert', 'that', 'whoever', 'gave', 'parole', 'submission', 'miss', 'myra', 'hindley', 'permission', 'give', 'that', 'miss', 'hindley', 'stage', 'gave', 'permission', 'anybody', 'part', 'with', 'that', 'statement', 'anyone', 'other', 'than', 'parole', 'board', 'three', 'other', 'people', 'intended', 'have', 'support', 'application', 'parole', 'copyright', 'that', 'long', 'statement', 'clearly', 'miss', 'hindley', 'newspaper', 'after', 'advertising', 'campaign', 'both', 'newspapers', 'television', 'then', 'proceeded', 'publish', 'series', 'articles', 'beginning', 'this', 'week', 'about', 'miss', 'myra', 'hindley', 'hopes', 'obtaining', 'parole', 'first', 'article', 'series', 'merited', 'very', 'large', 'headline', 'front', 'page', 'monday', '22nd', 'august', 'headed', 'myra', 'moors', 'killer', 'fights', 'freedom', 'there', 'large', 'picture', 'miss', 'hindley', 'front', 'page', 'with', 'comment', 'myra', 'hindley', 'this', 'moors', 'killer', 'looks', 'have', 'changed', 'second', 'page', 'which', 'continuation', 'text', 'a ...
# ['regina', 'secretary', 'state', 'homedepartment', 'parte', 'hindley', 'divisional', 'court', '1998', '751hearing', 'dates', 'december', '199718', 'december', '1997catchwords', 'prisons', 'prisoners', 'rights', 'release', 'licence', 'mandatory', 'life', 'sentence', 'prisoner', 'tariff', 'element', 'determinate', 'length', 'provisionally', 'fixed', 'communicated', 'prisoner', 'whole', 'life', 'tariff', 'subsequently', 'fixed', 'communicated', 'policy', 'review', 'whole', 'life', 'tariff', 'limited', 'considerations', 'retribution', 'deterrence', 'later', 'amended', 'take', 'account', 'exceptional', 'circumstances', 'whether', 'whole', 'life', 'tariff', 'lawful', 'whether', 'increase', 'from', 'determinate', 'tariff', 'lawful', 'whether', 'review', 'policy', 'lawful', 'criminal', 'justice', '1991', 'crime', 'sentences', '1997', '29headnote', '1966', 'applicant', 'defendant', 'were', 'convicted', 'murder', 'children', 'received', 'mandatory', 'life', 'sentences', 'applicant', 'also', 'convicted', 'being', 'accessory', 'after', 'fact', 'murder', 'third', 'child', 'which', 'defendant', 'convicted', 'sentenced', 'determinate', 'custodial', 'term', 'immediately', 'following', 'trial', 'judge', 'expressed', 'expectation', 'home', 'office', 'that', 'applicant', 'would', 'kept', 'prison', 'very', 'long', 'time', 'that', 'defendant', 'would', 'released', 'foreseeable', 'future', 'review', 'question', 'release', 'deferred', 'until', '1982', 'when', 'response', 'secretary', 'state', 'request', 'lord', 'chief', 'justice', 'recommended', 'that', 'while', 'would', 'never', 'release', 'defendant', 'term', 'less', 'that', 'years', 'would', 'appropriate', 'applicant', 'november', '1983', 'secretary', 'state', 'statement', 'parliament', 'announced', 'policy', 'release', 'mandatory', 'life', 'sentence', 'prisoners', 'exercise', 'discretion', 'under', 'criminal', 'justice', '1967', 'particular', 'that', 'sexual', 'sadistic', 'child', 'murderers', 'could', 'normally', 'expect', 'serve', 'tariff', 'period', 'least', 'years', 'satisfy', 'requirements', 'retribution', 'deterrence', 'although', 'longer', 'period', 'might', 'necessary', 'certain', 'cases', 'that', 'first', 'review', 'would', 'take', 'place', 'three', 'years', 'before', 'expiry', 'tariff', 'term', 'january', '1985', 'further', 'consultation', 'lord', 'chief', 'justice', 'confirmed', 'recommendation', 'secretary', 'state', 'reached', 'provisional', 'conclusion', 'that', 'years', 'would', 'appropriate', 'period', 'applicant', 'years', 'defendant', 'march', '1985', 'secretary', 'state', 'announced', 'parliament', 'that', 'case', 'prisoners', 'whose', 'tariff', 'longer', 'than', 'years', 'first', 'formal', 'review', 'parole', 'board', 'would', 'take', 'place', 'after', 'years', 'custody', 'referred', 'cases', 'applicant', 'defendant', 'board', 'which', 'declined', 'recommend', 'their', 'release', 'decided', 'review', 'case', 'applicant', 'five', 'years', 'that', 'defendant', 'years', 'that', 'time', 'applicant', 'told', 'could', 'have', 'calculated', 'provisional', 'year', 'period', '1987', 'applicant', 'confessed', 'police', 'complicity', 'murder', 'third', 'child', 'which', 'defendant', 'been', 'convicted', '1966', 'other', 'children', '1990', 'secretary', 'state', 'concluded', 'that', 'only', 'whole', 'life', 'tariff', 'appropriate', 'applicant', 'case', 'policy', 'announced', 'parliament', 'july', '1993', 'secretary', 'state', 'stated', 'that', 'exercise', 'release', 'discretion', 'confirmed', 'section', 'criminal', 'justiceact', '1991', 'prisoner', 'would', 'informed', 'tariff', 'judicial', 'recommendations', 'reasons', 'departing', 'from', 'them', 'that', 'exceptionally', 'tariff', 'might', 'increased', 'reduced', 'that', 'prisoner', 'might', 'make', 'representations', 'against', 'such', 'proposed', 'increase', 'december', '1994', 'secretary', 'state', 'announced', 'policy', 'respect', 'those', 'serving', 'whole', 'life', 'tariff', 'that', 'there', 'would', 'periodic', 'ministerial', 'r ...

# %%
def prepare_corpus(doc_clean):
    """
    Input  : clean document
    Purpose: create term dictionary of our courpus and Converting list of documents (corpus) into Document Term Matrix
    Output : term dictionary and Document Term Matrix
    """
    # Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
    dictionary = corpora.Dictionary(doc_clean)
    # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
    # generate LDA model
    return dictionary,doc_term_matrix

# %%
def create_gensim_lsa_model(doc_clean,number_of_topics,words):
    """
    Input  : clean document, number of topics and number of words associated with each topic
    Purpose: create LSA model using gensim
    Output : return LSA model
    """
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    # generate LSA model
    lsamodel = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
    #print(lsamodel.print_topics(num_topics=number_of_topics, num_words=words))
    return lsamodel

# %%
# LSA Model
number_of_topics=1
words=word_count_a
model=create_gensim_lsa_model(clean_text_a,number_of_topics,words)
words_law_article = dict(model.show_topic(0, topn=words))##dict and encoding matrix values

# %%
top_words_article = dict(model.show_topic(0, topn=5))

# %%
document_list,titles,word_count_b=load_data("","non-law-all.txt")
# Out:
# Number of words in text file : 34133
# Total Number of Documents: 4

# %%
clean_text_b=preprocess_data(document_list)
# Out:
# ['hardest', 'case', 'myra', 'hindley', 'life', 'sentences', 'rule', 'lawmyra', 'hindley', 'still', 'prison', 'years', 'after', 'conviction', 'twomurders', 'perpetrated', 'with', 'lover', 'brady', 'these', 'crimes', 'known', 'asthe', 'moors', 'murders', 'deeply', 'embedded', 'collective', 'consciousnessof', 'society', 'exaggeration', 'that', 'hindley', 'popularlyconsidered', 'embodiment', 'evil', 'over', 'last', 'years', 'hasmounted', 'legal', 'challenges', 'home', 'secretary', 'right', 'determine', 'thelength', 'detention', 'this', 'paper', 'argue', 'that', 'this', 'single', 'hardcase', 'irrevocable', 'effect', 'penal', 'policy', 'united', 'kingdom', 'thesis', 'that', 'hindley', 'mounted', 'these', 'challenges', 'positionof', 'home', 'secretary', 'hardened', 'main', 'because', 'politicalimpact', 'executive', 'action', 'that', 'could', 'lead', 'release', 'becausehindley', 'mandatory', 'life', 'prisoner', 'case', 'profoundimpact', 'relating', 'such', 'prisoners', 'prevented', 'fromremaining', 'step', 'with', 'relating', 'discretionary', 'life', 'prisoners', 'furthermore', 'position', 'executive', 'this', 'matter', 'firmlyentrenched', 'highly', 'unlikely', 'that', 'legal', 'position', 'willever', 'change', 'lord', 'goff', 'pointed', 'recent', 'case', 'dealing', 'with', 'anothernotorious', 'murder', 'sshd', 'parte', 'venables', '1997', 'publicdo', 'appreciate', 'what', 'life', 'sentence', 'means', 'further', 'however', 'suggest', 'that', 'legal', 'position', 'life', 'prisoner', 'often', 'understood', 'frequently', 'ignored', 'academic', 'community', 'thatreason', 'shall', 'begin', 'with', 'outline', 'legal', 'position', 'today', 'beforeexamining', 'historical', 'background', 'shall', 'then', 'examine', 'hindley', 'casein', 'detail', 'current', 'structurethere', 'currently', 'four', 'types', 'life', 'sentence', 'english', 'they', 'ever', 'have', 'feature', 'common', 'that', 'that', 'once', 'subject', 'life', 'sentencethe', 'prisoner', 'never', 'free', 'recalled', 'prison', 'until', 'theend', 'life', 'mandatory', 'lifethis', 'sentence', 'only', 'permissible', 'english', 'following', 'convictionfor', 'murder', 'after', 'sentencing', 'trial', 'judge', 'makes', 'recommendation', 'asto', 'period', 'years', 'prisoner', 'should', 'serve', 'satisfy', 'requirementsof', 'retribution', 'deterrence', 'tariff', 'lord', 'chief', 'justice', 'england', 'senior', 'criminal', 'judge', 'then', 'adds', 'comments', 'andrecommendation', 'different', 'from', 'trial', 'judge', 'home', 'secretarythen', 'makes', 'final', 'decision', 'tariff', 'figure', 'before', 'does', 'hemakes', 'initial', 'view', 'known', 'prisoner', 'discloses', 'paperworkon', 'which', 'basing', 'decision', 'prisoner', 'then', 'makerepresentations', 'prior', 'final', 'setting', 'tariff', 'when', 'prisonerhas', 'served', 'tariff', 'release', 'licence', 'possible', 'remains', 'whollywithin', 'discretion', 'home', 'secretary', 'decision', 'making', 'rolehowever', 'minister', 'subject', 'standard', 'administrative', 'lawrequirements', 'fairness', 'discretionary', 'lifeas', 'name', 'implies', 'this', 'sentence', 'passed', 'discretion', 'trialjudge', 'following', 'conviction', 'offence', 'which', 'life', 'imprisonment', 'isthe', 'maximum', 'sentencing', 'judge', 'announces', 'tariff', 'which', 'isfixed', 'this', 'point', 'immediately', 'expiration', 'tariff', 'prisoner', 'anoral', 'hearing', 'determine', 'whether', 'released', 'onlyconcern', 'being', 'risk', 'prisoner', 'presents', 'society', 'executivebranch', 'government', 'involved', 'save', 'that', 'home', 'secretary', 'aparty', 'this', 'hearing', 'which', 'adversarial', 'format', 'automatic', 'lifethis', 'introduced', 'crime', 'sentences', '1997', 'mandatory', 'with', 'certain', 'exceptions', 'following', 'conviction', 'second', 'serious', 'violent', 'orsexual', 'offence', 'however', 'identical', 'other', 'respects', 'thediscretionary', 'life', 'sentence', 'detention', 'majesty', 'pleasure', 'this', 'mandatory', 'sentence', 'passed', 'un ...
# ['scapegoat', 'exploration', 'media', 'representationsof', 'myra', 'hindley', 'rosemary', 'westthe', 'purpose', 'article', 'explore', 'girard', '1986', 'concept', 'thescapegoat', 'from', 'feminist', 'perspective', 'applying', 'media', 'representationsof', 'myra', 'hindley', 'rosemary', 'west', 'first', 'girard', 'theoreticalapproach', 'concept', 'scapegoat', 'outlined', 'secondly', 'articledescribes', 'some', 'theoretical', 'issues', 'which', 'surround', 'female', 'serialkillers', 'this', 'includes', 'analysis', 'media', 'representations', 'women', 'especially', 'they', 'criminal', 'thirdly', 'academic', 'literature', 'mediarepresentations', 'myra', 'hindley', 'rosemary', 'west', 'reviewed', 'fourthly', 'work', 'girard', '1986', 'applied', 'media', 'representations', 'myrahindley', 'rosemary', 'west', 'fifthly', 'noddings', '1989', 'used', 'demonstratehow', 'cultural', 'associations', 'between', 'women', 'evil', 'resultinghatred', 'female', 'bodies', 'implication', 'their', 'sexuality', 'underpin', 'thescapegoating', 'myra', 'hindley', 'rosemary', 'west', 'conclusion', 'thearticle', 'further', 'reflects', 'material', 'discussed', 'this', 'article', 'arises', 'long', 'standing', 'quaker', 'concern', 'thoseengaged', 'criminal', 'justice', 'system', 'newell', '2000', 'arriens', '2002', 'hoyle', '2002', 'apparent', 'inability', 'christian', 'communityat', 'large', 'participate', 'challenge', 'media', 'discourse', 'crime', 'andpunishment', 'curiosity', 'exploring', 'myra', 'hindley', 'androsemary', 'west', 'appear', 'have', 'borne', 'burden', 'responsibility', 'forthe', 'crimes', 'which', 'they', 'were', 'found', 'guilty', 'their', 'male', 'partners', 'crimeseem', 'have', 'been', 'largely', 'absolved', 'their', 'respective', 'roles', 'killingprocess', 'underpinning', 'this', 'discussion', 'acknowledgment', 'that', 'conceptof', 'retribution', 'rooted', 'judeo', 'christian', 'attitudes', 'towards', 'crime', 'andpunishment', 'historically', 'this', 'significant', 'determining', 'influenceon', 'development', 'criminal', 'justice', 'system', 'penal', 'policy', 'inbritain', 'gorringe', '1996', 'jones', '2002', 'provides', 'with', 'useful', 'evaluationof', 'this', 'legacy', 'urges', 'christians', 'with', 'commitment', 'socialjustice', 'incorporate', 'criminal', 'justice', 'system', 'into', 'their', 'vision', 'inaddition', 'many', 'christian', 'denominations', 'have', 'both', 'past', 'inthe', 'present', 'responded', 'creatively', 'challenges', 'posed', 'engagingwith', 'those', 'involved', 'with', 'criminal', 'justice', 'system', 'jones', 'andsedgwick', '2002', 'this', 'work', 'which', 'needs', 'more', 'widely', 'known', 'andcould', 'usefully', 'form', 'christian', 'theology', 'engagement', 'with', 'publicdiscourse', 'crime', 'punishment', 'this', 'leads', 'explore', 'conceptof', 'scapegoat', 'girard', '1986', 'explores', 'concept', 'scapegoat', 'through', 'differingaspects', 'collective', 'persecution', 'idea', 'collective', 'persecutionis', 'defined', 'acts', 'violence', 'dedicated', 'directly', 'particular', 'group', 'rabble', 'murderers', 'example', 'gives', 'persecution', 'thejews', 'during', 'black', 'death', 'this', 'distinguished', 'from', 'collectiveresonance', 'persecution', 'this', 'involves', 'acts', 'violence', 'such', 'witchhunts', 'which', 'legal', 'form', 'fuelled', 'extremes', 'publicopinion', 'however', 'distinction', 'between', 'collective', 'persecution', 'acollective', 'resonance', 'persecution', 'clear', 'currentexamples', 'both', 'collective', 'persecution', 'collective', 'resonance', 'ofpersecution', 'include', 'some', 'public', 'treatment', 'asylum', 'seekers', 'serialkillers', 'paedophiles', 'girard', '1986', 'suggests', 'that', 'there', 'three', 'stereotypes', 'that', 'contributeto', 'overall', 'stereotype', 'persecution', 'these', 'stereotype', 'ofcrisis', 'stereotype', 'accusation', 'stereotype', 'victims', 'describing', 'stereotype', 'crisis', 'girard', '1986', 'suggests', 'that', 'thisis', 'characterized', 'in ...
# ['when', 'chivalry', 'backfires', 'benevolent', 'sexismand', 'attitudes', 'toward', 'myra', 'hindleyg', 'tendayi', 'viki1', 'kristina', 'massey1', 'barbara', 'masser21university', 'kent', 'uk2university', 'queensland', 'australiaresearchers', 'have', 'suggested', 'that', 'paternalistic', 'attitudes', 'influence', 'people', 'sperceptions', 'female', 'offenders', 'current', 'study', 'examined', 'role', 'ofbenevolent', 'hostile', 'sexism', 'people', 'perceptions', 'specific', 'female', 'offender', 'myra', 'hindley', 'viewed', 'having', 'violated', 'traditional', 'gender', 'roleassumptions', 'observed', 'that', 'benevolent', 'sexism', 'hostile', 'sexism', 'relatedto', 'negative', 'evaluations', 'myra', 'hindley', 'addition', 'mediation', 'analyses', 'suggest', 'that', 'therelationship', 'between', 'benevolent', 'sexism', 'negative', 'evaluations', 'myra', 'hindleywas', 'partially', 'accounted', 'participants', 'perceptions', 'that', 'myra', 'hindley', 'possessedtraits', 'that', 'violated', 'traditional', 'gender', 'role', 'stereotypes', 'theoretical', 'practicalimplications', 'discussed', 'although', 'possible', 'that', 'women', 'offend', 'similar', 'rates', 'there', 'generalagreement', 'amongst', 'researchers', 'that', 'women', 'underrepresented', 'publishedcrime', 'statistics', 'heidensohn', '1991', 'example', '2001', 'only', 'the1', 'million', 'known', 'offenders', 'england', 'wales', 'were', 'female', 'home', 'officeofficial', 'statistics', '2003', 'given', 'reported', 'offending', 'rates', 'women', 'researchers', 'have', 'been', 'interested', 'examining', 'women', 'underrepresented', 'inpublished', 'crime', 'statistics', 'several', 'commentators', 'have', 'suggested', 'that', 'there', 'real', 'gender', 'differences', 'criminal', 'activity', 'that', 'female', 'offenders', 'treatedwith', 'comparative', 'leniency', 'within', 'criminal', 'justice', 'system', 'curran', '1983', 'kapardis', 'farrington', '1981', 'knuttschitt', 'green', '1984', 'steffenmeister', 'kramer', '1983', 'this', 'apparent', 'leniency', 'often', 'attributed', 'chivalry', 'anderson', '1976', 'campbell', '1977', 'pollak', '1950', 'simon', '1975', 'swigert', 'farrell', '1977', 'example', 'gelsthorpe', 'loucks', '1997', 'interviewed', 'magistrates', 'found', 'that', 'they', 'viewedfemale', 'offenders', 'more', 'sympathetically', 'therefore', 'were', 'more', 'inclined', 'helpthem', 'such', 'chivalrous', 'responses', 'female', 'offenders', 'part', 'driven', 'bystereotypical', 'expectations', 'concerning', 'comparatively', 'smaller', 'danger', 'thatfemale', 'offenders', 'pose', 'subsequent', 'perception', 'that', 'they', 'worthy', 'ofharsh', 'punishment1', 'sanderson', 'zanna', 'darley', '2000', 'with', 'regard', 'treatment', 'female', 'offenders', 'moulds', '1980', 'differentiatesbetween', 'chivalry', 'superficial', 'socially', 'acceptable', 'behaviours', 'paternalism', 'power', 'relationships', 'between', 'women', 'this', 'distinction', 'importantbecause', 'paternalism', 'actually', 'result', 'female', 'offenders', 'being', 'treated', 'more', 'harshlyby', 'criminal', 'justice', 'system', 'some', 'cases', 'nagel', '1981', 'saulter', 'tubbs', '1993', 'dowdsand', 'hedderman', '1997', 'suggest', 'that', 'offences', 'gendered', 'that', 'they', 'dividedinto', 'male', 'type', 'robbery', 'female', 'type', 'crimes', 'shoplifting', 'consistent', 'withthis', 'daly', '1989', 'found', 'that', 'preferential', 'treatment', 'women', 'criminal', 'justicesystem', 'limited', 'those', 'women', 'committed', 'acceptable', 'genderstereotype', 'consistent', 'types', 'crimes', 'research', 'suggests', 'that', 'those', 'women', 'commit', 'counter', 'stereotypical', 'crimesmay', 'line', 'with', 'paternalistic', 'model', 'criminal', 'justice', 'firstly', 'consideredin', 'terms', 'their', 'psychiatric', 'well', 'being', 'heidensohn', '1981', 'smart', '1977', 'wilczynski', '1997', 'female', 'offenders', 'have', 'committed', 'counter', 'stereotypicalcrimes', 'found', 'psychiatrically', 'unwell', ...
# ['truthwill', 'therole', 'judicial', 'advocacyand', 'gender', 'verdictconstructionthis', 'article', 'considers', 'largely', 'neglected', 'role', 'judicial', 'summing', 'contestedtrials', 'rhetoric', 'role', 'judge', 'independent', 'arbiter', 'using', 'trialsof', 'myra', 'hindley', 'rose', 'west', 'article', 'examines', 'relationship', 'between', 'thisrhetoric', 'reality', 'light', 'discretion', 'allowed', 'broad', 'nature', 'therules', 'regulating', 'summing', 'article', 'explores', 'this', 'rhetorical', 'space', 'canbe', 'used', 'exploited', 'that', 'becomes', 'form', 'judicial', 'advocacy', 'creating', 'newnarratives', 'lending', 'support', 'narratives', 'prosecution', 'defence', 'inparticular', 'article', 'argues', 'that', 'crucial', 'distinction', 'narratives', 'evident', 'thesummings', 'trials', 'rose', 'west', 'myra', 'hindley', 'appearance', 'thesexed', 'gendered', 'identities', 'women', 'introductionthe', 'tradition', 'legal', 'positivism', 'provides', 'basis', 'thetraditional', 'belief', 'that', 'trials', 'truth', 'discoverable', 'beelicited', 'when', 'facts', 'made', 'known', 'reason', 'lawapplied', 'nicolson', '1994', 'prime', 'arena', 'this', 'generally', 'taken', 'bethe', 'jury', 'trial', 'even', 'though', 'jury', 'trials', 'represent', 'less', 'than', 'percent', 'allcriminal', 'proceedings', 'majority', 'cases', 'heard', 'magistrates', 'courtor', 'disposed', 'guilty', 'plea', 'sanders', 'young', '2000', 'within', 'thisconception', 'trial', 'evidence', 'presented', 'witnesses', 'counsel', 'whilethe', 'judge', 'presides', 'independent', 'arbiter', 'performing', 'supervisory', 'role', 'zuckerman', '1989', 'ensuring', 'that', 'applicable', 'rules', 'conventions', 'arefollowed', 'judge', 'then', 'informs', 'jury', 'relevant', 'legal', 'rules', 'andrequirements', 'reminds', 'them', 'facts', 'judge', 'summing', 'froman', 'independent', 'standpoint', 'summarises', 'case', 'explains', 'legal', 'issues', 'incontention', 'comment', 'factors', 'which', 'lend', 'weight', 'cast', 'doubton', 'certain', 'evidence', 'white', '1985', 'finally', 'jury', 'retires', 'considers', 'thefacts', 'borne', 'evidence', 'returns', 'with', 'verdict', 'this', 'model', 'ofthe', 'trial', 'based', 'understanding', 'judge', 'jury', 'neutral', 'andvalue', 'free', 'sociolegal', 'research', 'challenged', 'this', 'perception', 'trial', 'process', 'arguing', 'that', 'verdict', 'culmination', 'trial', 'process', 'during', 'whichevidence', 'selected', 'excluded', 'events', 'interpreted', 'reinterpreted', 'shaped', 'reshaped', 'example', 'level', 'police', 'investigation', 'casesare', 'constructed', 'police', 'once', 'prima', 'facie', 'case', 'established', 'againstthe', 'accused', 'evidence', 'gathered', 'about', 'against', 'orher', 'with', 'view', 'proving', 'guilt', 'suspect', 'rather', 'than', 'presenting', 'allthat', 'discoverable', 'case', 'progresses', 'jury', 'trial', 'facts', 'discoveredby', 'investigation', 'mediated', 'counsel', 'whose', 'sole', 'objectiveis', 'case', 'form', 'argument', 'selection', 'witnesses', 'evidenceis', 'governed', 'much', 'wish', 'discover', 'what', 'most', 'likely', 'havehappened', 'counsel', 'need', 'present', 'plausible', 'account', 'events', 'tothe', 'jury', 'which', 'makes', 'sense', 'evidence', 'that', 'supports', 'theirposition', 'most', 'effective', 'doing', 'this', 'arrange', 'account', 'intoa', 'narrative', 'bennett', 'feldman', '1981', 'consequently', 'argued', 'thatthe', 'version', 'events', 'evidence', 'that', 'jury', 'presented', 'with', 'socialconstruction', 'reality', 'this', 'article', 'takes', 'examination', 'case', 'construction', 'further', 'examinesthe', 'final', 'stage', 'process', 'construction', 'summing', 'exploring', 'thenature', 'judge', 'role', 'this', 'stage', 'question', 'whether', 'that', 'role', 'accordswith', 'positivist', 'perception', 'judge', 'independent', 'arbiter', 'through', 'textualanalysis', 'summings', 'trials', 'rose', 'west', 'myra', 'hindley', 'iexplore', 'scope', 'discretion ...

# %%
# LSA Model
number_of_topics=1
words=word_count
model=create_gensim_lsa_model(clean_text_b,number_of_topics,words)
words_non_law_article =dict(model.show_topic(0, topn=words))#dict and encoding matrix values

# %%
top_non_law_article = dict(model_c.show_topic(0,topn=5))

# %%
top_words_article
# Out:
# {'tariff': 0.33293849716563323,
#  'secretari': 0.33147720211273735,
#  'prison': 0.24915911995674675,
#  'life': 0.23611708519236568,
#  'sentenc': 0.22952296370340297}

# %%
top_non_law_article
# Out:
# {'judg': 0.32073578367328615,
#  'evid': 0.3092444069593231,
#  'west': 0.28040281700236924,
#  'trial': 0.2772485745197229,
#  'case': 0.22810405823057162}

# %%
c={} #law words in non law
for key in top_words_article:
    try:
        c[key] = words_non_law_article[key]
    except KeyError:
        c[key] = 0

# %%
c
# Out:
# {'tariff': 0.036483731632387925,
#  'secretari': 0.02128251424217142,
#  'prison': 0.03639047810748174,
#  'life': 0.03741741504765616,
#  'sentenc': 0.04646241740792445}

# %%
top_non_law_article.update(c)

# %%
top_non_law_article
# Out:
# {'judg': 0.32073578367328615,
#  'evid': 0.3092444069593231,
#  'west': 0.28040281700236924,
#  'trial': 0.2772485745197229,
#  'case': 0.22810405823057162,
#  'tariff': 0.036483731632387925,
#  'secretari': 0.02128251424217142,
#  'prison': 0.03639047810748174,
#  'life': 0.03741741504765616,
#  'sentenc': 0.04646241740792445}

# %%
b={} #non law words in law
for key in top_non_law_article:
    try:
        b[key] = words_law_article[key]
    except KeyError:
        b[key] = 0

# %%
b
# Out:
# {'judg': 0.05935970953578713,
#  'evid': 0.009507116299140419,
#  'west': 0.0005793405702712192,
#  'trial': 0.024182678798960827,
#  'case': 0.15545250632649332,
#  'tariff': 0.33293849716563323,
#  'secretari': 0.33147720211273735,
#  'prison': 0.24915911995674675,
#  'life': 0.23611708519236568,
#  'sentenc': 0.22952296370340297}

# %%
top_words_article.update(b)

# %%
top_words_article
# Out:
# {'tariff': 0.33293849716563323,
#  'secretari': 0.33147720211273735,
#  'prison': 0.24915911995674675,
#  'life': 0.23611708519236568,
#  'sentenc': 0.22952296370340297,
#  'judg': 0.05935970953578713,
#  'evid': 0.009507116299140419,
#  'west': 0.0005793405702712192,
#  'trial': 0.024182678798960827,
#  'case': 0.15545250632649332}

# %%
# LSA Model
number_of_topics = 3 #
words = word_count_a
model = create_gensim_lsa_model(clean_text_a,number_of_topics,words)

a=pd.DataFrame()

for i in range(number_of_topics):
    words_from_law =dict(model.show_topic(i, topn=words))
    b=pd.DataFrame(words_from_law,index=[i])
    a=a.append(b)

a=a.transpose()



df = pd.DataFrame(columns=list(top_words_article.keys()), 
                  index = list(top_words_article.keys()))

l = list(top_words_article.keys())
print('cosine-similarity')
for i in l:
    for j in l:
            matrix=np.array([a.loc[i],a.loc[j]])
            n = s.metrics.pairwise.cosine_similarity(matrix, matrix, dense_output=True)
            df.loc[[i],[j]] = n[0,1]
print(df)

dfi.export(df, 'hello.png')
# Out:
# cosine-similarity
#              tariff secretari    prison       life   sentenc      judg  \
# tariff            1  0.983798  0.752886   0.981629  0.574831  0.467278
# secretari  0.983798         1  0.684687   0.938672  0.427497  0.337331
# prison     0.752886  0.684687         1   0.853834  0.833889  0.890528
# life       0.981629  0.938672  0.853834          1  0.712817  0.627305
# sentenc    0.574831  0.427497  0.833889   0.712817         1  0.949908
# judg       0.467278  0.337331  0.890528   0.627305  0.949908         1
# evid       0.156692  0.327257 -0.063293  0.0323719 -0.595669 -0.469139
# west       0.227186  0.387768 -0.306324  0.0462224 -0.666282  -0.70468
# trial      0.221077   0.11331  0.801684   0.396159  0.791636  0.940053
# case       0.633599  0.694786  0.736667   0.639247  0.241242    0.3966
#
#                 evid       west     trial      case
# tariff      0.156692   0.227186  0.221077  0.633599
# secretari   0.327257   0.387768   0.11331  0.694786
# prison     -0.063293  -0.306324  0.801684  0.736667
# life       0.0323719  0.0462224  0.396159  0.639247
# sentenc    -0.595669  -0.666282  0.791636  0.241242
# judg       -0.469139   -0.70468  0.940053    0.3966
# evid               1   0.851719 -0.363766   0.62186
# west        0.851719          1 -0.740681  0.290296
# trial      -0.363766  -0.740681         1  0.427808
# case         0.62186   0.290296  0.427808         1

# %%
df1 = df.to_numpy()

dist1 = list(df1[np.triu_indices(10, k = 1)])

# %%
# LSA Model
number_of_topics = 4 #
words = word_count_b
model = create_gensim_lsa_model(clean_text_b,number_of_topics,words)

a=pd.DataFrame()

for i in range(number_of_topics):
    words_from_law =dict(model.show_topic(i, topn=words))
    b=pd.DataFrame(words_from_law,index=[i])
    a=a.append(b)

a=a.transpose()



df = pd.DataFrame(columns=list(top_words_article.keys()), 
                  index = list(top_words_article.keys()))

l = list(top_words_article.keys())
print('cosine-similarity')
for i in l:
    for j in l:
            matrix=np.array([a.loc[i],a.loc[j]])
            n = s.metrics.pairwise.cosine_similarity(matrix, matrix, dense_output=True)
            df.loc[[i],[j]] = n[0,1]
print(df)

dfi.export(df, 'hello.png')
# Out:
# cosine-similarity
#               tariff  secretari     prison       life    sentenc       judg  \
# tariff             1   0.999325   0.998177   0.996725   0.988737 -0.0312698
# secretari   0.999325          1   0.997174   0.995374   0.993538 -0.0323026
# prison      0.998177   0.997174          1   0.999691    0.98644 -0.0433802
# life        0.996725   0.995374   0.999691          1   0.983745 -0.0610466
# sentenc     0.988737   0.993538    0.98644   0.983745          1 -0.0319897
# judg      -0.0312698 -0.0323026 -0.0433802 -0.0610466 -0.0319897          1
# evid       -0.197841  -0.198978  -0.207032  -0.223472  -0.197032   0.985121
# west        -0.26626  -0.282149  -0.226927  -0.221254  -0.316208   0.513522
# trial     -0.0873411 -0.0917632 -0.0905418  -0.105008  -0.099385   0.985122
# case        0.749558    0.74889   0.754368   0.745563   0.746004   0.594254
#
#                evid      west      trial      case
# tariff    -0.197841  -0.26626 -0.0873411  0.749558
# secretari -0.198978 -0.282149 -0.0917632   0.74889
# prison    -0.207032 -0.226927 -0.0905418  0.754368
# life      -0.223472 -0.221254  -0.105008  0.745563
# sentenc   -0.197032 -0.316208  -0.099385  0.746004
# judg       0.985121  0.513522   0.985122  0.594254
# evid              1  0.578296   0.985766  0.466265
# west       0.578296         1   0.652864  0.273676
# trial      0.985766  0.652864          1  0.572048
# case       0.466265  0.273676   0.572048         1

# %%
df1 = df.to_numpy()

dist2 = list(df1[np.triu_indices(10, k = 1)])

# %%
dist1 #law distances
# Out:
# [0.9837981884654161,
#  0.7528862881374415,
#  0.9816290103657856,
#  0.5748312002479229,
#  0.4672777595295246,
#  0.1566918717016346,
#  0.22718595517278378,
#  0.22107684886327125,
#  0.6335989914282464,
#  0.6846866805989494,
#  0.938672108494046,
#  0.42749740850426415,
#  0.33733116372492006,
#  0.3272568157886515,
#  0.38776767398329276,
#  0.11331010630132474,
#  0.6947862466092247,
#  0.8538338129806589,
#  0.8338891598859102,
#  0.8905276349582111,
#  -0.06329295250987327,
#  -0.30632449275263085,
#  0.8016839868357507,
#  0.7366667190568814,
#  0.7128174735658315,
#  0.6273047996534886,
#  0.032371918870161165,
#  0.04622244853796709,
#  0.3961591774092781,
#  0.6392471553199677,
#  0.9499080309199243,
#  -0.5956688415513042,
#  -0.6662817693523507,
#  0.7916360189026661,
#  0.2412419041366761,
#  -0.4691386544110278,
#  -0.704680338943085,
#  0.9400525843844477,
#  0.3965996026311073,
#  0.8517193067060852,
#  -0.3637661715496885,
#  0.6218602107527732,
#  -0.7406813477102862,
#  0.29029594882597143,
#  0.4278079711266452]

# %%
dist2 #non law distances
# Out:
# [0.9993250532072969,
#  0.998176557387009,
#  0.9967252178687431,
#  0.988736807109235,
#  -0.031269792147230295,
#  -0.19784086963084724,
#  -0.2662601529852098,
#  -0.08734110564391634,
#  0.7495579006105243,
#  0.9971737616155294,
#  0.9953738701741648,
#  0.9935381633556938,
#  -0.03230259053465887,
#  -0.19897804268523536,
#  -0.28214937917420596,
#  -0.09176315778314326,
#  0.7488897283347095,
#  0.9996905684222459,
#  0.986439997984196,
#  -0.04338016207928843,
#  -0.2070315126616561,
#  -0.226927030818883,
#  -0.09054179556667648,
#  0.7543684745889913,
#  0.983745073197515,
#  -0.06104657167944739,
#  -0.2234722017210383,
#  -0.221254299431398,
#  -0.10500830604282566,
#  0.7455627384259442,
#  -0.031989653516731886,
#  -0.19703183144919864,
#  -0.31620813247070156,
#  -0.09938497099240462,
#  0.7460041670777645,
#  0.9851206798026981,
#  0.513522435463045,
#  0.9851215039505481,
#  0.594253906160702,
#  0.5782958068906131,
#  0.9857661432584711,
#  0.4662651847582268,
#  0.6528642363709535,
#  0.27367571283655123,
#  0.5720476330437047]

# %%
mantel.test(dist1, dist2, perms=10000, method='pearson', tail='upper')
# Out:
# (0.3351340268541357, 0.0385, 2.1982037307664792)
